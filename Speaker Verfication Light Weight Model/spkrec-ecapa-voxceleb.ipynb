# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
# ...

# %%
# !pip install speechbrain

# %%
# !pip install numba

# %%
# %cd '/content/drive/MyDrive'
# !mkdir spkrec-ecapa-voxceleb
# %cd './spkrec-ecapa-voxceleb'

# %%
# %cd speechbrain
# !pip install -r requirements.txt
# !pip install -e .

# %%
# %cd './recipes/VoxCeleb/SpeakerRec'

# %%
# !python train_speaker_embeddings.py hparams/train_ecapa_tdnn.yaml --data_folder='/content/drive/MyDrive/spkrec-ecapa-voxceleb/speechbrain/data/train'
# Out:
# *************
#  classifier output neurons: 1599
# *************
# /content/drive/MyDrive/spkrec-ecapa-voxceleb/speechbrain/data/train/rirs_noises.zip exists. Skipping download
# /content/drive/MyDrive/spkrec-ecapa-voxceleb/speechbrain/data/train/rirs_noises.zip exists. Skipping download
# /content/drive/MyDrive/spkrec-ecapa-voxceleb/speechbrain/data/train/rirs_noises.zip exists. Skipping download
# is file: results/ecapa_augment/1986/save/train.csv
# is file: results/ecapa_augment/1986/save/dev.csv
# Skipping preparation, completed in previous run.
# ************
# finish data preparing
# ************
# add unk label
# speechbrain.core - Beginning experiment!
# speechbrain.core - Experiment folder: results/ecapa_augment/1986
# ************
# initializing speakerbrain
# ************
# speechbrain.core - Info: ckpt_interval_minutes arg from hparam file is used
# speechbrain.core - 21.1M trainable parameters in SpeakerBrain
# ************
# start training
# ************
# ...
